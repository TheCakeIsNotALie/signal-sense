# %%
# %matplotlib widget
import os
# Avoid Tensorflow yelling
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
from copy import deepcopy
from numpy.lib.stride_tricks import sliding_window_view
from pe_extractor.cnn import generator_nsb
import matplotlib.pyplot as plt
import numpy as np
from math import ceil
import tensorflow as tf

import importlib
import signal_sense
from signal_sense import accuracy_m, precision_m, recall_m, f1_m, get_model_summary
import pyeventio_binary_reader
from pyeventio_binary_reader import *

import itertools
import operator

importlib.reload(signal_sense)
importlib.reload(pyeventio_binary_reader)
# Out:
# <module 'pyeventio_binary_reader' from '/mnt/c/Users/yannis/Desktop/Hepia/Year4/projet_semestre_terzina/signal_sense/pyeventio_binary_reader.py'>

# %%
# generator variables
n_sample = 200000
n_sample_init = 0
batch_size = 1
shift_proba_bin = 30
sigma_smooth_pe_ns = 0 #2.
bin_size_ns = 0.20
sampling_rate_mhz = 1000 #200 MHz is the sampling rate of terzina
                        #250 SST1M
                        #1000 LST + MST
                        #résolution 100 picosecondes 
pe_rate_mhz = 150 # 1 to 150 MHz
noise_lsb=4. # 3.5 to 5.5 options
amplitude_gain=16.
relative_gain_std=0.05
# -------------------------------
# Generator data
# -------------------------------
sampling_period_s = 1 / (sampling_rate_mhz * 1e6)
bin_per_sample = ceil(((sampling_period_s) * 1e9) / bin_size_ns)

gen = generator_nsb(
    n_event=None, batch_size=batch_size, n_sample=n_sample + n_sample_init,
    n_sample_init=n_sample_init, pe_rate_mhz=pe_rate_mhz,
    bin_size_ns=bin_size_ns, sampling_rate_mhz=sampling_rate_mhz,
    amplitude_gain=amplitude_gain, noise_lsb=noise_lsb,
    sigma_smooth_pe_ns=sigma_smooth_pe_ns, baseline=0,
    relative_gain_std=relative_gain_std, shift_proba_bin=shift_proba_bin, dtype=np.float64,
    template_path='pulse_templates/LST_template_3ns.txt'
)

print(f"Using sampling period of {sampling_period_s}s")
print(f"Having {bin_per_sample} bins for every sample")
# Out:
# Using sampling period of 1e-09s
# Having 5 bins for every sample

# %% [markdown]
# # CNN 7 window size

# %%
# Model dependant variables
train_size = int(0.8 * n_sample)
window_size = 7

data = next(gen)
summed_bins = np.sum(data[1][0].reshape(-1, bin_per_sample), axis=1)
print("Generated data : ", data[0][0].shape)
print("Generated outputs : ", summed_bins.shape)
# summed_bins_bool = list(map(lambda x: 1 if x > 0 else 0, summed_bins))


sample_weights = signal_sense.compute_sample_weights(summed_bins)
print("Generated weights : ", sample_weights.shape)

sliced_data = sliding_window_view(data[0][0], window_size)
sliced_results = sliding_window_view(summed_bins, window_size)
sliced_weights = np.average(sliding_window_view(sample_weights, window_size), axis=1)
print(f"Sliced : data={sliced_data.shape}, results={sliced_results.shape}, weights={sliced_weights.shape}")
# print(sliced_weights)

# split the data into training/test data
dataset = list(zip(deepcopy(sliced_data), deepcopy(sliced_results), deepcopy(sliced_weights)))
# np.random.shuffle(dataset)

train_dataset, val_dataset = dataset[:train_size], dataset[train_size:]
np.random.shuffle(train_dataset)
train_data, train_results, train_weights = zip(*train_dataset)
train_data, train_results, train_weights = np.asarray(train_data), np.asarray(train_results), np.asarray(train_weights)
val_data, val_results, val_weights = zip(*val_dataset)
val_data, val_results, val_weights = np.asarray(val_data), np.asarray(val_results), np.asarray(val_weights)
print(f"Train : data={train_data.shape}, results={train_results.shape}, weights={train_weights.shape}")
print(f"Validation : data={val_data.shape}, results={val_results.shape}, weights={val_weights.shape}")
# Out:
# Generated data :  (200000,)
# Generated outputs :  (200000,)
# Generated weights :  (200000,)
# Sliced : data=(199994, 7), results=(199994, 7), weights=(199994,)
# Train : data=(160000, 7), results=(160000, 7), weights=(160000,)
# Validation : data=(39994, 7), results=(39994, 7), weights=(39994,)

# %%
model_name = 'cnn_model_rerun_1'
cnn_model_1 = model = tf.keras.Sequential(
    [
        tf.keras.layers.InputLayer(input_shape=(window_size, 1)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv1D(4, (4)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(16),
        tf.keras.layers.Dense(window_size, activation='relu'),
    ]
)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_1 (Bat  (None, 7, 1)              4
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 4, 4)              20
#
#  flatten_1 (Flatten)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dense_3 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 415 (1.62 KB)
# Trainable params: 413 (1.61 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # CNN 21 window size

# %%
# Model dependant variables
train_size = int(0.8 * n_sample)
window_size = 21

data = next(gen)
summed_bins = np.sum(data[1][0].reshape(-1, bin_per_sample), axis=1)
print("Generated data : ", data[0][0].shape)
print("Generated outputs : ", summed_bins.shape)
# summed_bins_bool = list(map(lambda x: 1 if x > 0 else 0, summed_bins))


sample_weights = signal_sense.compute_sample_weights(summed_bins)
print("Generated weights : ", sample_weights.shape)

sliced_data = sliding_window_view(data[0][0], window_size)
sliced_results = sliding_window_view(summed_bins, window_size)
sliced_weights = np.average(sliding_window_view(sample_weights, window_size), axis=1)
print(f"Sliced : data={sliced_data.shape}, results={sliced_results.shape}, weights={sliced_weights.shape}")
# print(sliced_weights)

# split the data into training/test data
dataset = list(zip(deepcopy(sliced_data), deepcopy(sliced_results), deepcopy(sliced_weights)))
# np.random.shuffle(dataset)

train_dataset, val_dataset = dataset[:train_size], dataset[train_size:]
np.random.shuffle(train_dataset)
train_data, train_results, train_weights = zip(*train_dataset)
train_data, train_results, train_weights = np.asarray(train_data), np.asarray(train_results), np.asarray(train_weights)
val_data, val_results, val_weights = zip(*val_dataset)
val_data, val_results, val_weights = np.asarray(val_data), np.asarray(val_results), np.asarray(val_weights)
print(f"Train : data={train_data.shape}, results={train_results.shape}, weights={train_weights.shape}")
print(f"Validation : data={val_data.shape}, results={val_results.shape}, weights={val_weights.shape}")
# Out:
# Generated data :  (200000,)
# Generated outputs :  (200000,)
# Generated weights :  (200000,)
# Sliced : data=(199980, 21), results=(199980, 21), weights=(199980,)
# Train : data=(160000, 21), results=(160000, 21), weights=(160000,)
# Validation : data=(39980, 21), results=(39980, 21), weights=(39980,)

# %%
model_name = 'cnn_model_rerun_2'
cnn_model_2 = model = tf.keras.Sequential(
    [
        tf.keras.layers.InputLayer(input_shape=(window_size, 1)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv1D(4, (11)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(32),
        tf.keras.layers.Dense(window_size, activation='relu'),
    ]
)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_2 (Bat  (None, 21, 1)             4
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 11, 4)             48
#
#  dropout (Dropout)           (None, 11, 4)             0
#
#  flatten_2 (Flatten)         (None, 44)                0
#
#  dense_4 (Dense)             (None, 32)                1440
#
#  dense_5 (Dense)             (None, 21)                693
#
# =================================================================
# Total params: 2185 (8.54 KB)
# Trainable params: 2183 (8.53 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
model_name = 'rnn_model_rerun_1'
rnn_model_1 = tf.keras.Sequential(
    [
        tf.keras.layers.InputLayer(input_shape=(window_size, 1)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.SimpleRNN(window_size),
        tf.keras.layers.Dense(window_size, activation='relu'),
    ]
)
rnn_model_1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_4 (Bat  (None, 21, 1)             4
#  chNormalization)
#
#  simple_rnn_1 (SimpleRNN)    (None, 21)                483
#
#  dense_7 (Dense)             (None, 21)                462
#
# =================================================================
# Total params: 949 (3.71 KB)
# Trainable params: 947 (3.70 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
model = rnn_model_1

checkpoint_filepath = f'./tmp/manual_rerun/{model_name}.keras'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True)
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)

log_dir = f"tmp/logs/manual_rerun_fit/{model_name}"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Get model summary
model_summary_str = get_model_summary(model)
# Log directory for TensorBoard
file_writer = tf.summary.create_file_writer(log_dir)
# Write the model summary to TensorBoard
with file_writer.as_default():
    tf.summary.text("Model Summary", model_summary_str, step=0)

model.compile(optimizer=adam_optimizer,
              loss='mse',
              metrics=[precision_m, recall_m, accuracy_m, f1_m])
#sample_weight=train_weights
history = model.fit(train_data, train_results, epochs=50, validation_data=(val_data, val_results), callbacks=[checkpoint_callback, tensorboard_callback])
# Out:
# Epoch 1/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0867 - precision_m: 0.5109 - recall_m: 0.6842 - accuracy_m: 0.8985 - f1_m: 0.5794 - val_loss: 0.0817 - val_precision_m: 0.5859 - val_recall_m: 0.6847 - val_accuracy_m: 0.9035 - val_f1_m: 0.6252
# Epoch 2/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0812 - precision_m: 0.5620 - recall_m: 0.7026 - accuracy_m: 0.9047 - f1_m: 0.6214 - val_loss: 0.0837 - val_precision_m: 0.4360 - val_recall_m: 0.7531 - val_accuracy_m: 0.9017 - val_f1_m: 0.5413
# Epoch 3/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0801 - precision_m: 0.5739 - recall_m: 0.7090 - accuracy_m: 0.9068 - f1_m: 0.6316 - val_loss: 0.0804 - val_precision_m: 0.5541 - val_recall_m: 0.7130 - val_accuracy_m: 0.9057 - val_f1_m: 0.6177
# Epoch 4/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0796 - precision_m: 0.5764 - recall_m: 0.7132 - accuracy_m: 0.9077 - f1_m: 0.6350 - val_loss: 0.0811 - val_precision_m: 0.5463 - val_recall_m: 0.7049 - val_accuracy_m: 0.9038 - val_f1_m: 0.6090
# Epoch 5/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0795 - precision_m: 0.5760 - recall_m: 0.7140 - accuracy_m: 0.9078 - f1_m: 0.6350 - val_loss: 0.0797 - val_precision_m: 0.5455 - val_recall_m: 0.7181 - val_accuracy_m: 0.9059 - val_f1_m: 0.6144
# Epoch 6/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0794 - precision_m: 0.5757 - recall_m: 0.7139 - accuracy_m: 0.9078 - f1_m: 0.6349 - val_loss: 0.0811 - val_precision_m: 0.4980 - val_recall_m: 0.7369 - val_accuracy_m: 0.9047 - val_f1_m: 0.5876
# Epoch 7/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0793 - precision_m: 0.5755 - recall_m: 0.7156 - accuracy_m: 0.9080 - f1_m: 0.6353 - val_loss: 0.0792 - val_precision_m: 0.5513 - val_recall_m: 0.7248 - val_accuracy_m: 0.9073 - val_f1_m: 0.6209
# Epoch 8/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0792 - precision_m: 0.5760 - recall_m: 0.7141 - accuracy_m: 0.9078 - f1_m: 0.6352 - val_loss: 0.0817 - val_precision_m: 0.4827 - val_recall_m: 0.7509 - val_accuracy_m: 0.9053 - val_f1_m: 0.5810
# Epoch 9/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0791 - precision_m: 0.5760 - recall_m: 0.7142 - accuracy_m: 0.9079 - f1_m: 0.6352 - val_loss: 0.0792 - val_precision_m: 0.5217 - val_recall_m: 0.7405 - val_accuracy_m: 0.9071 - val_f1_m: 0.6056
# Epoch 10/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0791 - precision_m: 0.5763 - recall_m: 0.7148 - accuracy_m: 0.9080 - f1_m: 0.6356 - val_loss: 0.0808 - val_precision_m: 0.5696 - val_recall_m: 0.7074 - val_accuracy_m: 0.9059 - val_f1_m: 0.6259
# Epoch 11/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0789 - precision_m: 0.5767 - recall_m: 0.7151 - accuracy_m: 0.9080 - f1_m: 0.6360 - val_loss: 0.0803 - val_precision_m: 0.5705 - val_recall_m: 0.7007 - val_accuracy_m: 0.9053 - val_f1_m: 0.6242
# Epoch 12/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0788 - precision_m: 0.5780 - recall_m: 0.7147 - accuracy_m: 0.9081 - f1_m: 0.6366 - val_loss: 0.0796 - val_precision_m: 0.5555 - val_recall_m: 0.7136 - val_accuracy_m: 0.9058 - val_f1_m: 0.6197
# Epoch 13/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0788 - precision_m: 0.5774 - recall_m: 0.7147 - accuracy_m: 0.9081 - f1_m: 0.6362 - val_loss: 0.0791 - val_precision_m: 0.5644 - val_recall_m: 0.7169 - val_accuracy_m: 0.9071 - val_f1_m: 0.6263
# Epoch 14/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0788 - precision_m: 0.5776 - recall_m: 0.7147 - accuracy_m: 0.9081 - f1_m: 0.6363 - val_loss: 0.0784 - val_precision_m: 0.5766 - val_recall_m: 0.7127 - val_accuracy_m: 0.9073 - val_f1_m: 0.6328
# Epoch 15/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0787 - precision_m: 0.5780 - recall_m: 0.7148 - accuracy_m: 0.9081 - f1_m: 0.6367 - val_loss: 0.0796 - val_precision_m: 0.5410 - val_recall_m: 0.7237 - val_accuracy_m: 0.9062 - val_f1_m: 0.6140
# Epoch 16/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0786 - precision_m: 0.5790 - recall_m: 0.7151 - accuracy_m: 0.9083 - f1_m: 0.6375 - val_loss: 0.0788 - val_precision_m: 0.5716 - val_recall_m: 0.7073 - val_accuracy_m: 0.9063 - val_f1_m: 0.6270
# Epoch 17/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0787 - precision_m: 0.5793 - recall_m: 0.7152 - accuracy_m: 0.9083 - f1_m: 0.6376 - val_loss: 0.0798 - val_precision_m: 0.5362 - val_recall_m: 0.7160 - val_accuracy_m: 0.9050 - val_f1_m: 0.6075
# Epoch 18/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0785 - precision_m: 0.5805 - recall_m: 0.7156 - accuracy_m: 0.9085 - f1_m: 0.6385 - val_loss: 0.0801 - val_precision_m: 0.5766 - val_recall_m: 0.7049 - val_accuracy_m: 0.9064 - val_f1_m: 0.6297
# Epoch 19/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0787 - precision_m: 0.5790 - recall_m: 0.7157 - accuracy_m: 0.9083 - f1_m: 0.6375 - val_loss: 0.0826 - val_precision_m: 0.6481 - val_recall_m: 0.6707 - val_accuracy_m: 0.9053 - val_f1_m: 0.6550
# Epoch 20/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0787 - precision_m: 0.5795 - recall_m: 0.7155 - accuracy_m: 0.9083 - f1_m: 0.6378 - val_loss: 0.0787 - val_precision_m: 0.5940 - val_recall_m: 0.7054 - val_accuracy_m: 0.9076 - val_f1_m: 0.6403
# Epoch 21/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0785 - precision_m: 0.5799 - recall_m: 0.7152 - accuracy_m: 0.9084 - f1_m: 0.6381 - val_loss: 0.0798 - val_precision_m: 0.5407 - val_recall_m: 0.7284 - val_accuracy_m: 0.9068 - val_f1_m: 0.6149
# Epoch 22/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0785 - precision_m: 0.5798 - recall_m: 0.7156 - accuracy_m: 0.9084 - f1_m: 0.6381 - val_loss: 0.0800 - val_precision_m: 0.6344 - val_recall_m: 0.6812 - val_accuracy_m: 0.9063 - val_f1_m: 0.6528
# Epoch 23/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0785 - precision_m: 0.5797 - recall_m: 0.7156 - accuracy_m: 0.9084 - f1_m: 0.6381 - val_loss: 0.0798 - val_precision_m: 0.5592 - val_recall_m: 0.7156 - val_accuracy_m: 0.9066 - val_f1_m: 0.6232
# Epoch 24/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0785 - precision_m: 0.5800 - recall_m: 0.7160 - accuracy_m: 0.9085 - f1_m: 0.6384 - val_loss: 0.0787 - val_precision_m: 0.5716 - val_recall_m: 0.7185 - val_accuracy_m: 0.9079 - val_f1_m: 0.6321
# Epoch 25/50
# 5000/5000 [==============================] - 88s 18ms/step - loss: 0.0784 - precision_m: 0.5799 - recall_m: 0.7165 - accuracy_m: 0.9086 - f1_m: 0.6385 - val_loss: 0.0787 - val_precision_m: 0.5446 - val_recall_m: 0.7241 - val_accuracy_m: 0.9066 - val_f1_m: 0.6160
# Epoch 26/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0785 - precision_m: 0.5793 - recall_m: 0.7158 - accuracy_m: 0.9084 - f1_m: 0.6379 - val_loss: 0.0779 - val_precision_m: 0.5801 - val_recall_m: 0.7119 - val_accuracy_m: 0.9077 - val_f1_m: 0.6345
# Epoch 27/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0785 - precision_m: 0.5795 - recall_m: 0.7159 - accuracy_m: 0.9084 - f1_m: 0.6379 - val_loss: 0.0789 - val_precision_m: 0.6121 - val_recall_m: 0.6924 - val_accuracy_m: 0.9069 - val_f1_m: 0.6459
# Epoch 28/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0784 - precision_m: 0.5799 - recall_m: 0.7169 - accuracy_m: 0.9087 - f1_m: 0.6388 - val_loss: 0.0797 - val_precision_m: 0.6398 - val_recall_m: 0.6736 - val_accuracy_m: 0.9053 - val_f1_m: 0.6518
# Epoch 29/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0784 - precision_m: 0.5792 - recall_m: 0.7171 - accuracy_m: 0.9086 - f1_m: 0.6384 - val_loss: 0.0792 - val_precision_m: 0.5406 - val_recall_m: 0.7304 - val_accuracy_m: 0.9072 - val_f1_m: 0.6162
# Epoch 30/50
# 5000/5000 [==============================] - 87s 17ms/step - loss: 0.0784 - precision_m: 0.5797 - recall_m: 0.7174 - accuracy_m: 0.9087 - f1_m: 0.6389 - val_loss: 0.0800 - val_precision_m: 0.5333 - val_recall_m: 0.7326 - val_accuracy_m: 0.9068 - val_f1_m: 0.6116
# Epoch 31/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0785 - precision_m: 0.5793 - recall_m: 0.7173 - accuracy_m: 0.9087 - f1_m: 0.6385 - val_loss: 0.0778 - val_precision_m: 0.5702 - val_recall_m: 0.7160 - val_accuracy_m: 0.9079 - val_f1_m: 0.6303
# Epoch 32/50
# 5000/5000 [==============================] - 82s 16ms/step - loss: 0.0783 - precision_m: 0.5800 - recall_m: 0.7181 - accuracy_m: 0.9088 - f1_m: 0.6394 - val_loss: 0.0799 - val_precision_m: 0.5654 - val_recall_m: 0.7146 - val_accuracy_m: 0.9066 - val_f1_m: 0.6267
# Epoch 33/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0784 - precision_m: 0.5790 - recall_m: 0.7185 - accuracy_m: 0.9088 - f1_m: 0.6389 - val_loss: 0.0785 - val_precision_m: 0.5478 - val_recall_m: 0.7308 - val_accuracy_m: 0.9078 - val_f1_m: 0.6203
# Epoch 34/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0784 - precision_m: 0.5786 - recall_m: 0.7180 - accuracy_m: 0.9087 - f1_m: 0.6384 - val_loss: 0.0784 - val_precision_m: 0.6021 - val_recall_m: 0.6985 - val_accuracy_m: 0.9071 - val_f1_m: 0.6424
# Epoch 35/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0782 - precision_m: 0.5805 - recall_m: 0.7187 - accuracy_m: 0.9090 - f1_m: 0.6400 - val_loss: 0.0799 - val_precision_m: 0.5376 - val_recall_m: 0.7192 - val_accuracy_m: 0.9055 - val_f1_m: 0.6103
# Epoch 36/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0783 - precision_m: 0.5791 - recall_m: 0.7191 - accuracy_m: 0.9089 - f1_m: 0.6392 - val_loss: 0.0788 - val_precision_m: 0.5655 - val_recall_m: 0.7133 - val_accuracy_m: 0.9070 - val_f1_m: 0.6259
# Epoch 37/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0782 - precision_m: 0.5797 - recall_m: 0.7185 - accuracy_m: 0.9089 - f1_m: 0.6395 - val_loss: 0.0800 - val_precision_m: 0.6509 - val_recall_m: 0.6739 - val_accuracy_m: 0.9059 - val_f1_m: 0.6583
# Epoch 38/50
# 5000/5000 [==============================] - 82s 16ms/step - loss: 0.0782 - precision_m: 0.5799 - recall_m: 0.7187 - accuracy_m: 0.9089 - f1_m: 0.6395 - val_loss: 0.0797 - val_precision_m: 0.5578 - val_recall_m: 0.7211 - val_accuracy_m: 0.9074 - val_f1_m: 0.6248
# Epoch 39/50
# 5000/5000 [==============================] - 83s 17ms/step - loss: 0.0782 - precision_m: 0.5796 - recall_m: 0.7183 - accuracy_m: 0.9089 - f1_m: 0.6394 - val_loss: 0.0787 - val_precision_m: 0.5676 - val_recall_m: 0.7157 - val_accuracy_m: 0.9072 - val_f1_m: 0.6283
# Epoch 40/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0782 - precision_m: 0.5802 - recall_m: 0.7188 - accuracy_m: 0.9090 - f1_m: 0.6398 - val_loss: 0.0803 - val_precision_m: 0.6258 - val_recall_m: 0.6784 - val_accuracy_m: 0.9050 - val_f1_m: 0.6466
# Epoch 41/50
# 5000/5000 [==============================] - 86s 17ms/step - loss: 0.0783 - precision_m: 0.5799 - recall_m: 0.7185 - accuracy_m: 0.9089 - f1_m: 0.6394 - val_loss: 0.0784 - val_precision_m: 0.5738 - val_recall_m: 0.7202 - val_accuracy_m: 0.9083 - val_f1_m: 0.6346
# Epoch 42/50
# 5000/5000 [==============================] - 84s 17ms/step - loss: 0.0782 - precision_m: 0.5799 - recall_m: 0.7181 - accuracy_m: 0.9088 - f1_m: 0.6394 - val_loss: 0.0786 - val_precision_m: 0.5768 - val_recall_m: 0.7107 - val_accuracy_m: 0.9072 - val_f1_m: 0.6326
# Epoch 43/50
# 5000/5000 [==============================] - 84s 17ms/step - loss: 0.0782 - precision_m: 0.5800 - recall_m: 0.7184 - accuracy_m: 0.9089 - f1_m: 0.6395 - val_loss: 0.0800 - val_precision_m: 0.5833 - val_recall_m: 0.6994 - val_accuracy_m: 0.9055 - val_f1_m: 0.6322
# Epoch 44/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0782 - precision_m: 0.5798 - recall_m: 0.7186 - accuracy_m: 0.9089 - f1_m: 0.6395 - val_loss: 0.0798 - val_precision_m: 0.6088 - val_recall_m: 0.6916 - val_accuracy_m: 0.9064 - val_f1_m: 0.6440
# Epoch 45/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0782 - precision_m: 0.5798 - recall_m: 0.7187 - accuracy_m: 0.9090 - f1_m: 0.6395 - val_loss: 0.0789 - val_precision_m: 0.5732 - val_recall_m: 0.7076 - val_accuracy_m: 0.9066 - val_f1_m: 0.6282
# Epoch 46/50
# 5000/5000 [==============================] - 84s 17ms/step - loss: 0.0782 - precision_m: 0.5796 - recall_m: 0.7190 - accuracy_m: 0.9090 - f1_m: 0.6395 - val_loss: 0.0796 - val_precision_m: 0.5415 - val_recall_m: 0.7333 - val_accuracy_m: 0.9076 - val_f1_m: 0.6180
# Epoch 47/50
# 5000/5000 [==============================] - 84s 17ms/step - loss: 0.0781 - precision_m: 0.5802 - recall_m: 0.7192 - accuracy_m: 0.9091 - f1_m: 0.6400 - val_loss: 0.0786 - val_precision_m: 0.5887 - val_recall_m: 0.7074 - val_accuracy_m: 0.9075 - val_f1_m: 0.6382
# Epoch 48/50
# 5000/5000 [==============================] - 84s 17ms/step - loss: 0.0782 - precision_m: 0.5814 - recall_m: 0.7187 - accuracy_m: 0.9091 - f1_m: 0.6406 - val_loss: 0.0801 - val_precision_m: 0.4934 - val_recall_m: 0.7505 - val_accuracy_m: 0.9059 - val_f1_m: 0.5891
# Epoch 49/50
# 5000/5000 [==============================] - 85s 17ms/step - loss: 0.0782 - precision_m: 0.5798 - recall_m: 0.7188 - accuracy_m: 0.9089 - f1_m: 0.6395 - val_loss: 0.0793 - val_precision_m: 0.6024 - val_recall_m: 0.6917 - val_accuracy_m: 0.9061 - val_f1_m: 0.6399
# Epoch 50/50
# 5000/5000 [==============================] - 84s 17ms/step - loss: 0.0782 - precision_m: 0.5804 - recall_m: 0.7188 - accuracy_m: 0.9090 - f1_m: 0.6399 - val_loss: 0.0787 - val_precision_m: 0.6002 - val_recall_m: 0.7030 - val_accuracy_m: 0.9074 - val_f1_m: 0.6429

# %% [markdown]
# # TensorBoard training visualisation
# Launch the command `tensorboard --logdir tmp/logs/{fit_folder}` in the terminal and access the website link.

# %% [markdown]
# # Data and results visualisation

# %%
# --------------------------------
# Moving window display
# --------------------------------
i = 0
resultsYMax = np.max(val_results) + 0.1
fig = plt.figure(figsize=(12, 5))

def update():
    plt.clf()
    ax1 = plt.subplot(211)
    ax1.plot(val_data[i], label='Sensor data')
    ax1.set_ylabel('Amplitude')
    ax1.legend()
    
    ax2 = plt.subplot(212, sharex=ax1)
    ax2.set_ylim(-0.1,resultsYMax)
    ax2.set_ylabel('Number of pe events')
    ax2.plot(val_results[i], label='Truth')
    # [None, ] is for the batch array dimension, since it's a single event, just add none
    ax2.plot(model.predict(val_data[i][None,], verbose=0)[0], '--', label='Prediction')
    ax2.legend()
    
    plt.xlabel('Sample index')
    plt.draw()

def press(event):
    global i, ax1, ax2
    # Move window left or right
    if event.key == 'left':
        i-=1
    elif event.key == 'right':
        i+=1
    update()

fig.canvas.mpl_connect('key_press_event', press)
update()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# --------------------------------
# Whole waveform display
# --------------------------------

fig = plt.figure(figsize=(12, 5))
fig.suptitle('Waveform PE event prediction')
ax1 = plt.subplot(211)
ax1.plot(data[0][0], label='Sensor data')
ax1.set_ylabel('Amplitude')
ax1.legend()
ax2 = plt.subplot(212, sharex=ax1)
ax2.set_ylabel('Number of pe events')
ax2.plot(summed_bins, label='Truth')
# results = model.predict(sliced_data)
# avg_results = signal_sense.reaggregate_windows_avg(results, window_size, window_size-1)
# ax2.plot(avg_results, label='Prediction')
ax2.legend()
plt.xlabel('Sample index')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Model's metrics with different configurations

# %%
configs = {
    "pe_rate_mhz": [20,50,64,150], # 1 to 150 MHz [20,32,50,64,128,150]
    "noise_lsb": np.arange(0, 1.51, 0.25), # 0 to 1.5 noise
}

metrics_result = signal_sense.run_tests(model, configs, window_size)
# Out:
# Running 28 tests on model
# RUN_0: config={'pe_rate_mhz': 20, 'noise_lsb': 0.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_1: config={'pe_rate_mhz': 20, 'noise_lsb': 0.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_2: config={'pe_rate_mhz': 20, 'noise_lsb': 0.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_3: config={'pe_rate_mhz': 20, 'noise_lsb': 0.75} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_4: config={'pe_rate_mhz': 20, 'noise_lsb': 1.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_5: config={'pe_rate_mhz': 20, 'noise_lsb': 1.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_6: config={'pe_rate_mhz': 20, 'noise_lsb': 1.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_7: config={'pe_rate_mhz': 50, 'noise_lsb': 0.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_8: config={'pe_rate_mhz': 50, 'noise_lsb': 0.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_9: config={'pe_rate_mhz': 50, 'noise_lsb': 0.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_10: config={'pe_rate_mhz': 50, 'noise_lsb': 0.75} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_11: config={'pe_rate_mhz': 50, 'noise_lsb': 1.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_12: config={'pe_rate_mhz': 50, 'noise_lsb': 1.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_13: config={'pe_rate_mhz': 50, 'noise_lsb': 1.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_14: config={'pe_rate_mhz': 64, 'noise_lsb': 0.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_15: config={'pe_rate_mhz': 64, 'noise_lsb': 0.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_16: config={'pe_rate_mhz': 64, 'noise_lsb': 0.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_17: config={'pe_rate_mhz': 64, 'noise_lsb': 0.75} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_18: config={'pe_rate_mhz': 64, 'noise_lsb': 1.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_19: config={'pe_rate_mhz': 64, 'noise_lsb': 1.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_20: config={'pe_rate_mhz': 64, 'noise_lsb': 1.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_21: config={'pe_rate_mhz': 150, 'noise_lsb': 0.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_22: config={'pe_rate_mhz': 150, 'noise_lsb': 0.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_23: config={'pe_rate_mhz': 150, 'noise_lsb': 0.5} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_24: config={'pe_rate_mhz': 150, 'noise_lsb': 0.75} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_25: config={'pe_rate_mhz': 150, 'noise_lsb': 1.0} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_26: config={'pe_rate_mhz': 150, 'noise_lsb': 1.25} | bps=10 | input=(100000,) | expected_output=(100000,)
# RUN_27: config={'pe_rate_mhz': 150, 'noise_lsb': 1.5} | bps=10 | input=(100000,) | expected_output=(100000,)

# %%
grouped_by_pe_rate = [{ "label": f"{k}Mhz", "data" : list(g)} for k, g in itertools.groupby(metrics_result, key=operator.itemgetter('pe_rate_mhz'))]

fig = plt.figure(figsize=(12, 5))
fig.suptitle('Model\'s precision by configuration')

x = np.arange(len(grouped_by_pe_rate))
bar_width = 0.1
bar_colormap = signal_sense.get_colormap(configs["noise_lsb"])

bar_labels = []
bar_values = []
bar_locations = []
bar_colors = []

ax = fig.subplots(1)
for i, entry in enumerate(grouped_by_pe_rate):    
    bar_labels.extend([x["noise_lsb"] for x in entry["data"]])
    cur_values = [x["precision_m"] for x in entry["data"]]
    bar_values.extend(cur_values)
    bar_locations.extend(i + np.arange(len(cur_values)) * (bar_width + 0.01))
    bar_colors.extend([bar_colormap[str(x["noise_lsb"])] for x in entry["data"]])
    
rects = ax.bar(bar_locations, bar_values, bar_width, label=bar_labels, color=bar_colors)
ax.bar_label(rects, label_type='center', rotation = 90, padding=3)

# Add X axis labels
ax.set_xticks(x, [x["label"] for x in grouped_by_pe_rate])

# Draw color legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(by_label.values(), by_label.keys(), title="LSB Noise")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
grouped_by_pe_rate = [{ "label": f"{k}Mhz", "data" : list(g)} for k, g in itertools.groupby(metrics_result, key=operator.itemgetter('pe_rate_mhz'))]

fig = plt.figure(figsize=(12, 5))
fig.suptitle('Model\'s recall by configuration')

x = np.arange(len(grouped_by_pe_rate))
bar_width = 0.1
bar_colormap = signal_sense.get_colormap(configs["noise_lsb"])

bar_labels = []
bar_values = []
bar_locations = []
bar_colors = []

ax = fig.subplots(1)
for i, entry in enumerate(grouped_by_pe_rate):    
    bar_labels.extend([x["noise_lsb"] for x in entry["data"]])
    cur_values = [x["recall_m"] for x in entry["data"]]
    bar_values.extend(cur_values)
    bar_locations.extend(i + np.arange(len(cur_values)) * (bar_width + 0.01))
    bar_colors.extend([bar_colormap[str(x["noise_lsb"])] for x in entry["data"]])
    
rects = ax.bar(bar_locations, bar_values, bar_width, label=bar_labels, color=bar_colors)
ax.bar_label(rects, label_type='center', rotation = 90, padding=3)

# Add X axis labels
ax.set_xticks(x, [x["label"] for x in grouped_by_pe_rate])

# Draw color legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(by_label.values(), by_label.keys(), title="LSB Noise")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model = tf.keras.models.load_model('tmp/manual_fit_1_noSampleWeights.keras', 
                                   custom_objects={
                                       "precision_m": precision_m,
                                       "recall_m": recall_m,
                                       "f1_m": f1_m
                                       })

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_1 (Bat  (None, 21, 1)             4
#  chNormalization)
#
#  conv_4x11 (Conv1D)          (None, 11, 4)             48
#
#  dropout_1 (Dropout)         (None, 11, 4)             0
#
#  flatten_1 (Flatten)         (None, 44)                0
#
#  conv_32 (Dense)             (None, 32)                1440
#
#  output_21 (Dense)           (None, 21)                693
#
# =================================================================
# Total params: 2185 (8.54 KB)
# Trainable params: 2183 (8.53 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________
